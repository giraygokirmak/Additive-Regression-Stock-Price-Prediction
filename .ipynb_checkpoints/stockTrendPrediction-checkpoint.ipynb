# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 
import pandas_datareader.data as web
from dateutil.relativedelta import relativedelta
import datetime
from fbprophet import Prophet
from fbprophet.diagnostics import cross_validation,performance_metrics
from fbprophet.plot import plot_cross_validation_metric
import plotly.offline as py
import plotly.graph_objs as go
py.init_notebook_mode(connected=True)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipywidgets/widgets/widget.py:281: DeprecationWarning:
#
# Widget registration using a string name has been deprecated. Widget registration now uses a plain `@register` decorator.
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
def veri_al(hisse_kodu,res="yahoo"):
    baslangic = datetime.date.today() - relativedelta(years=yil)
    bitis = datetime.date.today()
    df = web.DataReader(hisse_kodu, res, baslangic, bitis).dropna()   
    return df

# %%
hisse_kodu = 'THYAO.IS'
yil = 5
ay = 3
np.random.seed(13)

# %%
hisse_verisi = veri_al(hisse_kodu)
orgDatLen = hisse_verisi.shape[0]

# %%
hisse_verisi = hisse_verisi.reset_index().rename(columns={'Date':'ds', 'Adj Close':'y'})
hisse_verisi['y'] = np.log(hisse_verisi['y'])

# %%
future = pd.DataFrame()
future['ds'] = pd.bdate_range(hisse_verisi['ds'][0], pd.datetime.today()+pd.DateOffset(months=ay))

# %%
# %%time
model = Prophet(changepoint_prior_scale=1)
model.fit(hisse_verisi)
# Out:
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# CPU times: user 5.06 s, sys: 55 ms, total: 5.11 s
# Wall time: 6.42 s

# %%
# %%time
forecast = model.predict(future)
# Out:
# CPU times: user 16 s, sys: 18.9 s, total: 35 s
# Wall time: 28.9 s

# %%
figure = py.iplot({"data": [
    go.Scatter(x=hisse_verisi['ds'], y=np.exp(hisse_verisi['y']), name='Fiyat'),
    go.Scatter(x=forecast['ds'], y=np.exp(forecast['yhat']), name='Tahmin'),
    go.Scatter(x=forecast['ds'], y=np.exp(forecast['yhat_upper']), fill='tonexty', name='Üst sınır'),
    go.Scatter(x=forecast['ds'], y=np.exp(forecast['yhat_lower']), fill='tonexty', name='Alt sınır'),
    go.Scatter(x=forecast['ds'], y=np.exp(forecast['trend']), name='Trend')]})
# Out:
# <div id="853e6200-07c4-42eb-8c07-50804398cf7d" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("853e6200-07c4-42eb-8c07-50804398cf7d", [{"y": [8.279999732971191, 8.260000228881834, 8.260000228881834, 7.999999999999998, 7.820000171661377, 7.920000076293947, 7.8600001335144025, 7.65999984741211, 7.760000228881834, 7.699999809265137, 7.5399999618530265, 7.15999984741211, 7.21999979019165, 7.119999885559082, 7.360000133514404, 7.480000019073486, 7.6399998664855975, 7.4000000953674325, 7.559999942779541, 7.480000019073486, 7.5399999618530265, 7.65999984741211, 7.460000038146974, 7.420000076293947, 7.4000000953674325, 7.480000019073486, 7.480000019073486, 7.139999866485595, 7.079999923706054, 6.999999999999999, 7.199999809265136, 7.21999979019165, 7.179999828338624, 7.239999771118164, 7.059999942779541, 7.199999809265136, 7.239999771118164, 6.800000190734864, 6.920000076293944, 6.599999904632568, 6.599999904632568, 6.34000015258789, 6.579999923706055, 6.199999809265137, 6.0, 5.800000190734863, 6.360000133514403, 6.44000005722046, 6.44000005722046, 6.360000133514403, 6.4099998474121085, 6.7100000381469735, 6.84000015258789, 6.7899999618530265, 6.869999885559082, 7.110000133514404, 7.170000076293946, 7.21999979019165, 7.320000171661377, 7.179999828338624, 6.7899999618530265, 7.010000228881837, 7.130000114440918, 7.260000228881836, 6.989999771118165, 7.070000171661377, 7.070000171661377, 6.920000076293944, 7.019999980926514, 6.980000019073486, 6.739999771118164, 6.750000000000001, 6.940000057220459, 6.989999771118165, 7.130000114440918, 7.039999961853028, 7.039999961853028, 7.010000228881837, 7.059999942779541, 7.179999828338624, 7.110000133514404, 7.070000171661377, 6.849999904632568, 6.780000209808349, 6.909999847412109, 6.849999904632568, 6.869999885559082, 6.6599998474121085, 6.579999923706055, 6.539999961853027, 6.579999923706055, 6.34000015258789, 6.550000190734864, 6.550000190734864, 6.679999828338622, 6.309999942779541, 6.019999980926514, 6.090000152587891, 6.179999828338623, 6.28000020980835, 6.230000019073486, 6.2899999618530265, 6.400000095367432, 6.130000114440917, 6.190000057220459, 6.139999866485597, 6.0, 6.090000152587891, 6.28000020980835, 6.199999809265137, 6.349999904632568, 6.590000152587891, 6.6599998474121085, 6.84000015258789, 6.820000171661378, 6.829999923706054, 6.869999885559082, 6.909999847412109, 6.730000019073486, 6.750000000000001, 6.7100000381469735, 6.780000209808349, 6.6599998474121085, 6.7199997901916495, 6.769999980926515, 6.84000015258789, 6.900000095367432, 6.820000171661378, 6.820000171661378, 6.7100000381469735, 6.539999961853027, 6.590000152587891, 6.559999942779541, 6.750000000000001, 6.750000000000001, 6.750000000000001, 6.6500000953674325, 6.690000057220459, 6.6599998474121085, 6.760000228881837, 6.699999809265138, 6.800000190734864, 6.929999828338622, 7.079999923706054, 6.869999885559082, 6.889999866485596, 6.889999866485596, 6.869999885559082, 6.969999790191651, 7.050000190734863, 7.050000190734863, 7.150000095367432, 7.070000171661377, 7.039999961853028, 7.119999885559082, 7.130000114440918, 7.190000057220459, 7.130000114440918, 7.039999961853028, 7.130000114440918, 7.210000038146973, 7.179999828338624, 7.190000057220459, 6.889999866485596, 6.880000114440918, 6.670000076293945, 6.619999885559082, 6.6599998474121085, 6.690000057220459, 6.699999809265138, 6.639999866485596, 6.639999866485596, 6.599999904632568, 6.630000114440918, 6.550000190734864, 6.559999942779541, 6.489999771118164, 6.34000015258789, 6.34000015258789, 6.489999771118164, 6.499999999999999, 6.619999885559082, 6.510000228881836, 6.679999828338622, 6.599999904632568, 6.750000000000001, 6.780000209808349, 6.829999923706054, 6.820000171661378, 6.739999771118164, 6.630000114440918, 6.619999885559082, 6.6500000953674325, 6.6500000953674325, 6.6500 ...

# %%
fig = model.plot_components(forecast)

# %%
cv = cross_validation(model, horizon = '66 days')
# Out:
# INFO:fbprophet.diagnostics:Making 48 forecasts with cutoffs between 2014-05-21 00:00:00 and 2018-08-19 00:00:00

# %%
p = performance_metrics(cv)
p.head()
# Out:
#      horizon       mse      rmse       mae      mape  coverage
# 4     7 days  0.004259  0.065261  0.049843  0.022975  0.455752
# 1650  7 days  0.004257  0.065243  0.049789  0.022944  0.460177
# 288   7 days  0.004257  0.065244  0.049790  0.022945  0.460177
# 1508  7 days  0.004257  0.065243  0.049783  0.022944  0.460177
# 709   7 days  0.004246  0.065159  0.049623  0.022855  0.464602

# %%
fig = plot_cross_validation_metric(cv, metric='mape')

# %%
print('RMSE: %f' % np.sqrt(np.mean((forecast.loc[:orgDatLen, 'yhat']-hisse_verisi['y'])**2)) )
# Out:
# RMSE: 0.047467

# %%
bugun_tahmini = forecast.loc[:orgDatLen+2].tail(2)[['ds','yhat']]
bugun_tahmini['yhat'] = np.exp(bugun_tahmini['yhat'])
bugun_tahmini['ds'] = bugun_tahmini['ds'].astype(str)
degisim = bugun_tahmini['yhat'].pct_change()
print("{0} tahmini: %{1:,.4f}".format((bugun_tahmini['ds'].values[1]),bugun_tahmini['yhat'].pct_change().values[-1]*100))
# Out:
# 2018-10-25 tahmini: %0.6582
